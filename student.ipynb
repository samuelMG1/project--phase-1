# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Samuel gathogo
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\SAMMY\Documents\FLATIRON\P1_PROJECT\AviationData.csv',encoding = 'windows-1252',low_memory=False)
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country   Latitude   Longitude Airport.Code  \
# 0  MOOSE CREEK, ID  United States        NaN         NaN          NaN
# 1   BRIDGEPORT, CA  United States        NaN         NaN          NaN
# 2    Saltville, VA  United States  36.922223  -81.878056          NaN
# 3       EUREKA, CA  United States        NaN         NaN          NaN
# 4       Canton, OH  United States        NaN         NaN          NaN
#
#   Airport.Name  ... Purpose.of.flight Air.carrier Total.Fatal.Injuries  \
# 0          NaN  ...          Personal         NaN                  2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50132 non-null  object
#  9   Airport.Name            52704 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87507 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %%
df.isnull().sum()
# Out:
# Event.Id                      0
# Investigation.Type            0
# Accident.Number               0
# Event.Date                    0
# Location                     52
# Country                     226
# Latitude                  54507
# Longitude                 54516
# Airport.Code              38757
# Airport.Name              36185
# Injury.Severity            1000
# Aircraft.damage            3194
# Aircraft.Category         56602
# Registration.Number        1382
# Make                         63
# Model                        92
# Amateur.Built               102
# Number.of.Engines          6084
# Engine.Type                7096
# FAR.Description           56866
# Schedule                  76307
# Purpose.of.flight          6192
# Air.carrier               72241
# Total.Fatal.Injuries      11401
# Total.Serious.Injuries    12510
# Total.Minor.Injuries      11933
# Total.Uninjured            5912
# Weather.Condition          4492
# Broad.phase.of.flight     27165
# ...

# %% [markdown]
# # Calculating the  percentage of null values

# %%
null_percentage = round(df.isnull().sum()/len(df)*100).sort_values(ascending=False)

null_percentage
# Out:
# Schedule                  86.0
# Air.carrier               81.0
# FAR.Description           64.0
# Aircraft.Category         64.0
# Latitude                  61.0
# Longitude                 61.0
# Airport.Code              44.0
# Airport.Name              41.0
# Broad.phase.of.flight     31.0
# Publication.Date          15.0
# Total.Serious.Injuries    14.0
# Total.Fatal.Injuries      13.0
# Total.Minor.Injuries      13.0
# Engine.Type                8.0
# Number.of.Engines          7.0
# Purpose.of.flight          7.0
# Total.Uninjured            7.0
# Report.Status              7.0
# Weather.Condition          5.0
# Aircraft.damage            4.0
# Registration.Number        2.0
# Injury.Severity            1.0
# Event.Id                   0.0
# Amateur.Built              0.0
# Investigation.Type         0.0
# Make                       0.0
# Country                    0.0
# Location                   0.0
# Event.Date                 0.0
# Accident.Number            0.0
# ...

# %%
df.shape
# Out:
# (88889, 31)

# %%
df['Broad.phase.of.flight']= df['Broad.phase.of.flight'].fillna("Unknown")

# %%
df['Broad.phase.of.flight'].unique()
# Out:
# array(['Cruise', 'Unknown', 'Approach', 'Climb', 'Takeoff', 'Landing',
#        'Taxi', 'Descent', 'Maneuvering', 'Standing', 'Go-around', 'Other'],
#       dtype=object)

# %%
mode_value = df['Aircraft.Category'].mode()[0]  # Get the most frequent value
df['Aircraft.Category'].fillna(mode_value, inplace=True)
# Out:
# C:\Users\SAMMY\AppData\Local\Temp\ipykernel_18868\3517530640.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Aircraft.Category'].fillna(mode_value, inplace=True)

# %%
#normalizing the column Make 
df["Make"]=df["Make"].str.upper()

# %%
df['Aircraft.Category'].unique()
# Out:
# array(['Airplane', 'Helicopter', 'Glider', 'Balloon', 'Gyrocraft',
#        'Ultralight', 'Unknown', 'Blimp', 'Powered-Lift', 'Weight-Shift',
#        'Powered Parachute', 'Rocket', 'WSFT', 'UNK', 'ULTR'], dtype=object)

# %%
empty=['Latitude','Longitude','Air.carrier','Schedule','FAR.Description']
df.drop(columns = empty,inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Airport.Code            50132 non-null  object
#  7   Airport.Name            52704 non-null  object
#  8   Injury.Severity         87889 non-null  object
#  9   Aircraft.damage         85695 non-null  object
#  10  Aircraft.Category       88889 non-null  object
#  11  Registration.Number     87507 non-null  object
#  12  Make                    88826 non-null  object
#  13  Model                   88797 non-null  object
# ...

# %%
df.shape
# Out:
# (88889, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Airport.Code            50132 non-null  object
#  7   Airport.Name            52704 non-null  object
#  8   Injury.Severity         87889 non-null  object
#  9   Aircraft.damage         85695 non-null  object
#  10  Aircraft.Category       88889 non-null  object
#  11  Registration.Number     87507 non-null  object
#  12  Make                    88826 non-null  object
#  13  Model                   88797 non-null  object
# ...

# %%
empty=['Airport.Code','Airport.Name']
df.drop(columns = empty,inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Aircraft.Category       88889 non-null  object
#  9   Registration.Number     87507 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
# ...

# %%
df['Publication.Date'] = pd.to_datetime(df['Publication.Date'])
# Out:
# C:\Users\SAMMY\AppData\Local\Temp\ipykernel_18868\3025418559.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Publication.Date'] = pd.to_datetime(df['Publication.Date'])

# %%
df['Publication.Date'].ffill(inplace=True)
# Out:
# C:\Users\SAMMY\AppData\Local\Temp\ipykernel_18868\1884450917.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Publication.Date'].ffill(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Aircraft.Category       88889 non-null  object
#  9   Registration.Number     87507 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
# ...

# %%
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
#
#           Location        Country Injury.Severity Aircraft.damage  \
# 0  MOOSE CREEK, ID  United States        Fatal(2)       Destroyed
# 1   BRIDGEPORT, CA  United States        Fatal(4)       Destroyed
# 2    Saltville, VA  United States        Fatal(3)       Destroyed
# 3       EUREKA, CA  United States        Fatal(2)       Destroyed
# 4       Canton, OH  United States        Fatal(1)       Destroyed
#
#   Aircraft.Category Registration.Number  ...    Engine.Type Purpose.of.flight  \
# 0          Airplane              NC6404  ...  Reciprocating          Personal
# ...

# %%
mode_value = df['Report.Status'].mode()[0]  # Get the most frequent value
df['Report.Status'].fillna(mode_value, inplace=True)
# Out:
# C:\Users\SAMMY\AppData\Local\Temp\ipykernel_18868\3341958550.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Report.Status'].fillna(mode_value, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Injury.Severity         87889 non-null  object
#  7   Aircraft.damage         85695 non-null  object
#  8   Aircraft.Category       88889 non-null  object
#  9   Registration.Number     87507 non-null  object
#  10  Make                    88826 non-null  object
#  11  Model                   88797 non-null  object
#  12  Amateur.Built           88787 non-null  object
#  13  Number.of.Engines       82805 non-null  float64
# ...

# %%
df= df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63622 entries, 1 to 88767
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                63622 non-null  object
#  1   Investigation.Type      63622 non-null  object
#  2   Accident.Number         63622 non-null  object
#  3   Event.Date              63622 non-null  object
#  4   Location                63622 non-null  object
#  5   Country                 63622 non-null  object
#  6   Injury.Severity         63622 non-null  object
#  7   Aircraft.damage         63622 non-null  object
#  8   Aircraft.Category       63622 non-null  object
#  9   Registration.Number     63622 non-null  object
#  10  Make                    63622 non-null  object
#  11  Model                   63622 non-null  object
#  12  Amateur.Built           63622 non-null  object
#  13  Number.of.Engines       63622 non-null  float64
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
# Displaying the top columns
df.head()
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 6  20001218X45446           Accident      CHI81LA106  1981-08-01
# 7  20020909X01562           Accident      SEA82DA022  1982-01-01
# 8  20020909X01561           Accident      NYC82DA015  1982-01-01
#
#            Location        Country Injury.Severity Aircraft.damage  \
# 1    BRIDGEPORT, CA  United States        Fatal(4)       Destroyed
# 3        EUREKA, CA  United States        Fatal(2)       Destroyed
# 6        COTTON, MN  United States        Fatal(4)       Destroyed
# 7       PULLMAN, WA  United States       Non-Fatal     Substantial
# 8  EAST HANOVER, NJ  United States       Non-Fatal     Substantial
#
#   Aircraft.Category Registration.Number  ...    Engine.Type Purpose.of.flight  \
# 1          Airplane              N5069P  ...  Reciprocating          Personal
# ...

# %%
df.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88639  20221011106092           Accident      CEN23LA008  2022-10-06
# 88647  20221011106098           Accident      ERA23LA014  2022-10-08
# 88661  20221018106153           Accident      CEN23LA015  2022-10-13
# 88735  20221031106231           Accident      CEN23LA023  2022-10-29
# 88767  20221109106272           Accident      CEN23LA033  2022-11-09
#
#              Location        Country Injury.Severity Aircraft.damage  \
# 88639        Iola, TX  United States       Non-Fatal     Substantial
# 88647      Dacula, GA  United States       Non-Fatal     Substantial
# 88661     Ardmore, OK  United States       Non-Fatal     Substantial
# 88735     Houston, TX  United States           Minor     Substantial
# 88767  Bridgeport, TX  United States       Non-Fatal     Substantial
#
#       Aircraft.Category Registration.Number  ...    Engine.Type  \
# 88639          Airplane              N18158  ...  Reciprocating
# ...

# %%
#summary of statistics
df.describe()
# Out:
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       63622.000000          63622.000000            63622.000000
# mean            1.119094              0.387665                0.209754
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# 75%             1.000000              0.000000                0.000000
# max             8.000000            270.000000               81.000000
# std             0.387572              2.737680                0.777849
#
#        Total.Minor.Injuries  Total.Uninjured               Publication.Date
# count          63622.000000     63622.000000                          63622
# mean               0.283047         2.275722  2002-05-22 22:17:05.079374976
# min                0.000000         0.000000            1982-01-01 00:00:00
# ...

# %%
#data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63622 entries, 1 to 88767
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                63622 non-null  object
#  1   Investigation.Type      63622 non-null  object
#  2   Accident.Number         63622 non-null  object
#  3   Event.Date              63622 non-null  object
#  4   Location                63622 non-null  object
#  5   Country                 63622 non-null  object
#  6   Injury.Severity         63622 non-null  object
#  7   Aircraft.damage         63622 non-null  object
#  8   Aircraft.Category       63622 non-null  object
#  9   Registration.Number     63622 non-null  object
#  10  Make                    63622 non-null  object
#  11  Model                   63622 non-null  object
#  12  Amateur.Built           63622 non-null  object
#  13  Number.of.Engines       63622 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Event.Id                  0
# Investigation.Type        0
# Accident.Number           0
# Event.Date                0
# Location                  0
# Country                   0
# Injury.Severity           0
# Aircraft.damage           0
# Aircraft.Category         0
# Registration.Number       0
# Make                      0
# Model                     0
# Amateur.Built             0
# Number.of.Engines         0
# Engine.Type               0
# Purpose.of.flight         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Weather.Condition         0
# Broad.phase.of.flight     0
# Report.Status             0
# Publication.Date          0
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Analysis of accidents distribution over time

# %%
df['Date'] = pd.to_datetime(df['Event.Date'])
df['Year'] = df['Date'].dt.year
accidents_per_year = df['Year'].value_counts().sort_index()
accidents_per_year
# Out:
# Year
# 1962       1
# 1977       1
# 1981       1
# 1982    3478
# 1983    3392
# 1984    3300
# 1985    2977
# 1986    2737
# 1987    2683
# 1988    2586
# 1989    2427
# 1990    2391
# 1991    2355
# 1992    2267
# 1993    2207
# 1994    2076
# 1995    2136
# 1996    2030
# 1997    1927
# 1998    1982
# 1999    1972
# 2000    1849
# 2001       3
# 2002       1
# 2003       2
# 2005       1
# 2006       3
# 2007      79
# 2008    1521
# 2009    1449
# 2010    1395
# 2011    1437
# 2012    1441
# 2013    1168
# 2014    1139
# 2015    1163
# 2016    1210
# 2017    1171
# 2018    1170
# 2019    1042
# 2020     727
# 2021     316
# 2022     409
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting the graph showing trends of accidents

# %%
sns.lineplot(x=accidents_per_year.index, y=accidents_per_year.values)
plt.title('Number of Accidents per Year')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.grid(True)
plt.show()
# Out:
# c:\Users\SAMMY\anaconda03\envs\learn-env\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\SAMMY\anaconda03\envs\learn-env\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# From the visualization above, we can note that:
#
# Before 1980, there were no aeroplanes. The year 1980 recorded the highest number of accidents. As the years progress, the number of accidents is reducing due to improvements in skilled manpower and technology, though more research needs to be done.

# %% [markdown]
# ### Accidents over time and aircraft category

# %%
Aircrafts = df.groupby('Aircraft.Category')['Make'].count()
Aircrafts
# Out:
# Aircraft.Category
# Airplane             61167
# Balloon                 24
# Blimp                    1
# Glider                 120
# Gyrocraft              134
# Helicopter            1941
# Powered Parachute       79
# Ultralight              15
# Unknown                  2
# WSFT                     1
# Weight-Shift           138
# Name: Make, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Aircraft.Category', order=df['Aircraft.Category'].value_counts().index, color= 'green')
plt.title('Distribution of Accidents by Aircraft Category') # 
plt.xlabel('Aircraft Category')
plt.ylabel('Number of Accidents') 
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.yscale('log')  # Use a logarithmic scale for better visualization of the data
plt.show()

# %% [markdown]
# the matplot shows the highest number of accidents per aircraft category 1 where airplane and helicopter had most accidents in the distribution category

# %% [markdown]
# ### Accidents over time by make

# %%
top_makes = df['Make'].value_counts().nlargest(20).index
top_makes
# Out:
# Index(['CESSNA', 'PIPER', 'BEECH', 'BELL', 'MOONEY', 'GRUMMAN', 'BELLANCA',
#        'HUGHES', 'BOEING', 'ROBINSON', 'AERONCA', 'AIR TRACTOR', 'MAULE',
#        'CHAMPION', 'SCHWEIZER', 'STINSON', 'AERO COMMANDER', 'LUSCOMBE',
#        'TAYLORCRAFT', 'HILLER'],
#       dtype='object', name='Make')

# %%
plt.figure(figsize=(14, 6))
sns.countplot(data=df[df['Make'].isin(top_makes)], x='Make', order=top_makes)
plt.title('Top 10 Makes with Most Accidents')
plt.xlabel('Make')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# CESSNA has most accidents compared to top 10 other aircrafts

# %% [markdown]
# ### Analysis at what point the accident happened

# %%
## plotting a bar graph of broad of phase of flight 
plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Broad.phase.of.flight', order=df['Broad.phase.of.flight'].value_counts().index) #
plt.title('Number of Accidents by Broad Phase of Flight')
plt.xlabel('Number of Accidents')
plt.ylabel('Broad Phase of Flight')
plt.show()

# %% [markdown]
# This visualization shows that the occurrence of accidents in the phase of flight is unknown but most cases happen when landing and take off

# %% [markdown]
# ### Distribution of Total Fatal, serious and minor injuries

# %%
phase_of_flight_data = df.groupby('Broad.phase.of.flight').agg(
    total_incidents=('Event.Id', 'count'),
    total_fatal_injuries=('Total.Fatal.Injuries', 'sum'),
    total_serious_injuries=('Total.Serious.Injuries', 'sum'),
    total_minor_injuries=('Total.Minor.Injuries', 'sum')
).reset_index()
phase_of_flight_data
# Out:
#    Broad.phase.of.flight  total_incidents  total_fatal_injuries  \
# 0               Approach             4885                2827.0
# 1                  Climb             1513                1470.0
# 2                 Cruise             7863                4769.0
# 3                Descent             1335                 742.0
# 4              Go-around             1051                 451.0
# 5                Landing            11366                 364.0
# 6            Maneuvering             6329                4038.0
# 7                  Other               89                  69.0
# 8               Standing              526                  81.0
# 9                Takeoff             9672                3128.0
# 10                  Taxi             1422                  35.0
# 11               Unknown            17571                6690.0
#
#     total_serious_injuries  total_minor_injuries
# 0                   1436.0                1944.0
# ...

# %%
plt.figure(figsize=(14, 8))
plt.subplot(2, 1, 1)
plt.bar(phase_of_flight_data['Broad.phase.of.flight'], phase_of_flight_data['total_incidents'], color='blue')
plt.title('Total Incidents by Phase of Flight')
plt.xlabel('Phase of Flight')
plt.ylabel('Total Incidents')
plt.xticks(rotation=45)
plt.grid(True)
plt.subplot(2, 1, 2)
plt.bar(phase_of_flight_data['Broad.phase.of.flight'], phase_of_flight_data['total_fatal_injuries'], color='red', alpha=0.5, label='Fatal Injuries')
plt.bar(phase_of_flight_data['Broad.phase.of.flight'], phase_of_flight_data['total_serious_injuries'], color='pink', alpha=0.5, label='Serious Injuries')
plt.bar(phase_of_flight_data['Broad.phase.of.flight'], phase_of_flight_data['total_minor_injuries'], color='black', alpha=0.5, label='Minor Injuries')
plt.title('Total Injuries by Phase of Flight')
plt.xlabel('Phase of Flight')
plt.ylabel('Total Injuries')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# plotting: Two subplots are created:
#
# The first subplot shows the total number of incidents by phase of flight. The second subplot shows the total number of fatal, serious, and minor injuries by phase of flight, differentiated by color (hue). This visualization will help you understand the distribution of incidents and injuries across different phases of flight.
